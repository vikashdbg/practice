# %%
#importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# loading data sheets using pandas.

# %%
df = pd.read_excel("C:\\Users\\vikas\\OneDrive\\Desktop\\New folder (3)\\Data sheet for practice.xlsx")
temp=df.isna().sum().sum() # checking number of null value in data sheet
print("total number of null value is : ",temp)

df.head()# structure of data sheeet
# Out:
# total number of null value is :  129
#          Date  System Flow\n(w1)  Final\nOut TOC\n(w2)  \
# 0  06-02-2020                210                   242
# 1  06-02-2020                220                   239
# 2  06-02-2020                230                   216
# 3  07-02-2020                230                   195
# 4  07-02-2020                250                   182
#
#    Final\nOut Turbidity\n(w3)  Final\nOut TSS\n(w4)  Final\nOut pH\n(w8)  \
# 0                       76.20                   260                 6.50
# 1                       99.48                   232                 6.80
# 2                       65.82                   232                 6.84
# 3                       88.00                   280                 6.84
# 4                       35.00                   190                 6.66
#
#    PST\nVisual\n(g4)  PST\nOut PH\n(g9)  PST\nSludge Wasting\n(m³/hr)\n(g2)  \
# 0                  7               7.37                                 5.0
# 1                  6               7.52                                 5.0
# 2                  6               7.52                                 5.0
# 3                  6               7.52                                 5.0
# 4                  4               7.66                                 5.0
#
#    PST\nOut TSS \n(g6)  ...  Post Treatment\nin TUR\n(From ACT 2)  \
# 0                 1710  ...                                   834
# 1                 1710  ...                                   788
# 2                  330  ...                                   788
# 3                  810  ...                                   811
# 4                  980  ...                                   689
#
#    Post Treatment\nin TUR\n(x3)  Post Treatment\nOut TUR\n(S2 O/L)\n(x4)  \
# 0                           440                                    43.20
# 1                           409                                    79.26
# 2                           429                                    56.58
# 3                           446                                    88.00
# 4                           360                                    47.00
#
#    Post Treatment\nin TOC\n(From S1)  Post Treatment\nin TOC\n(From ACT 2)  \
# 0                              263.0                                   482
# 1                              202.0                                   472
# 2                              188.0                                   561
# 3                              207.0                                   522
# 4                              109.0                                   636
#
#    Post Treatment\nin TOC\n(x5)  Post Treatment\nOut TOC\n(S2 O/L)\n(x6)  \
# 0                           336                                      251
# 1                           300                                      254
# 2                           334                                      216
# 3                           330                                      196
# 4                           341                                      182
#
#    Post Treatment\nOut PH\n(S2 O/L)\n(x7)  \
# 0                                    6.29
# 1                                    6.56
# 2                                    6.53
# 3                                    6.49
# 4                                    6.28
#
#    Post Treatment\nOut FLOW\n(S2 O/L)\n(X8)   \
# 0                                        210
# 1                                        220
# 2                                        230
# 3                                        230
# 4                                        250
#
#    pH Adjst\nOut pH\n(From Final)\n(p1)
# 0                                   6.50
# 1                                   6.80
# 2                                   6.84
# 3                                   6.84
# 4                                   6.66
#
# [5 rows x 106 columns]

# %%
col_arr=np.array(df.columns)
col_arr
# Out:
# array(['Date', 'System Flow\n(w1)', 'Final\nOut TOC\n(w2)',
#        'Final\nOut Turbidity\n(w3)', 'Final\nOut TSS\n(w4)',
#        'Final\nOut pH\n(w8)', 'PST\nVisual\n(g4)', 'PST\nOut PH\n(g9)',
#        'PST\nSludge Wasting\n(m³/hr)\n(g2)', 'PST\nOut TSS \n(g6)',
#        'PST\nSV\n(g11)', 'HT\nOut flow\n(a6)', 'HT\nOut TOC\n(a4)',
#        'HT\nOut pH\n(a2)', 'HT \nEmpty Volume (m³)\n(a8)', 'HT\nOut TN',
#        'HT\nOut TP', 'ACT 1 \nin TOC\n(d1)', 'ACT 1\nOut TOC\n(d2)',
#        'ACT 1\nin TN\n(d3)', 'ACT 1\nOut TN\n(d4)', 'ACT 1\nin TP\n(d5)',
#        'ACT 1\nOut TP\n(d6)', 'ACT 1\nOUR\n(d7)', 'ACT 1\nDO\n(d11)',
#        'ACT 1\ninlet Flow\n(d12)', 'ACT 1\ninlet pH (d13)',
#        'ACT 1\nReactor pH\n(d18)', 'ACT 1\nTemp\n(d20)',
#        'ACT 1\nin Ammonia\n(d22)', 'ACT 1\nOut Ammonia\n(d23)',
#        'ACT 1 specialist\nSCORING\n(by Himal)',
#        'AHR\nin TOC\n(From ACT 1)\n(c1)', 'AHR \nOut TOC\n(c2)',
#        'AHR\nTVA\n(c3)', 'AHR\nAlkalinity\n(c4)',
#        'AHR\nTotal in flow\n(from PH Adjust 1)',
#        'AHR\nin Flow\n(From ACT 1)\n(c5)',
#        'AHR \nBP in Flow\n(From HT)\n(c6)',
#        'AHR\nBP in TOC\n(From HT)\n(c7)', 'AHR\nCirculation\n(c8) ',
#        'AHR\nMLSS\n(c9)', 'AHR\nTemp\n(c12)',
#        'AHR\nin PH\n(After PH Adjust)\n(c10)', 'AHR\nOut PH\n(c13)',
#        'ACT 2\nin TOC\n(From ACT 1)', 'ACT 2\nin TOC\n(From AHR)',
#        'ACT 2\nin TOC\n(y1)', 'ACT 2\nOut TOC\n(y2)',
#        'ACT 2\nOut TN\n(y4)', 'ACT 2\nOut TP\n(y6)', 'ACT 2\nOUR\n(y7)',
#        'ACT 2\nDO\n(y11)', 'ACT 2\nOut TURB', 'ACT 2\nOut TSS',
#        'ACT 2\ninlet Flow\n(From ACT 1)', 'ACT 2\ninlet Flow\n(From AHR)',
#        'ACT 2\ninlet Flow\n(y12)', 'ACT 2\nBP in Flow\n(From SFT)\n(y15)',
#        'ACT 2\nBP in TOC\n(From SFT)\n(y16)',
#        'ACT 2\nBP in pH\n(From SFT)\n(y14)', 'ACT 2\nReactor pH\n(y18)',
#        'ACT 2\nTemp\n(y20)', 'ASP\nin TOC\n(From ACT 2)',
#        'ASP\nin TOC\n(From AHR)', 'ASP\nin TOC\n(z1)',
#        'ASP\nOut TOC\n(z2)', 'ASP\nOut TN\n(z4)', 'ASP\nOut TP\n(z6)',
#        'ASP\nOUR\n(z7)', 'ASP\nMLSS\n(z9)', 'ASP\nSV\n(z10)',
#        'ASP\nDO\n(z11)', 'ASP\ninlet Flow\n(From ACT 2)',
#        'ASP\ninlet Flow\n(From AHR)', 'ASP\ninlet Flow\n(z12)',
#        'ASP\nBP in pH\n(From SFT)\n(z14)',
#        'ASP\nBP in flow\n(From SFT)\n(z15)',
#        'ASP\nBP in TOC\n(From SFT)\n(z16)', 'ASP\nMLVSS\n(z17)',
#        'ASP\nReactor pH\n(z18)', 'ASP\nCirculation\n(z19)',
#        'ASP\nTemp\n(z20)', 'S1\nOut Turb\n(t1)',
#        'S1\nSludge Wasting\n(m³/hr)\n(t2)', 'S1\nVisual\n(t4)',
#        'S1\nOut TSS\n(t6)', 'S1\nOut TOC\n(t8)', 'S1\nSV\n(t10)',
#        'Post Treatment\nin FLOW\n(From S1)',
#        'Post Treatment\nin FLOW\n(From ACT 2)',
#        'Post Treatment\nin TSS\n(From S1)',
#        'Post Treatment\nin TSS\n(From ACT 2)',
#        'Post Treatment\nin TSS\n(x1)',
#        'Post Treatment\nOut TSS\n(S2 O/L)\n(x2)',
#        'Post Treatment\nin TUR\n(From S1)',
#        'Post Treatment\nin TUR\n(From ACT 2)',
#        'Post Treatment\nin TUR\n(x3)',
#        'Post Treatment\nOut TUR\n(S2 O/L)\n(x4)',
#        'Post Treatment\nin TOC\n(From S1)',
#        'Post Treatment\nin TOC\n(From ACT 2)',
#        'Post Treatment\nin TOC\n(x5)',
#        'Post Treatment\nOut TOC\n(S2 O/L)\n(x6)',
#        'Post Treatment\nOut PH\n(S2 O/L)\n(x7)',
#        'Post Treatment\nOut FLOW\n(S2 O/L)\n(X8) ',
#        'pH Adjst\nOut pH\n(From Final)\n(p1) '], dtype=object)

# %%
arr=dict(df.dtypes) # data types of all column.
arr
# Out:
# {'Date': dtype('O'),
#  'System Flow\n(w1)': dtype('int64'),
#  'Final\nOut TOC\n(w2)': dtype('int64'),
#  'Final\nOut Turbidity\n(w3)': dtype('float64'),
#  'Final\nOut TSS\n(w4)': dtype('int64'),
#  'Final\nOut pH\n(w8)': dtype('float64'),
#  'PST\nVisual\n(g4)': dtype('int64'),
#  'PST\nOut PH\n(g9)': dtype('float64'),
#  'PST\nSludge Wasting\n(m³/hr)\n(g2)': dtype('float64'),
#  'PST\nOut TSS \n(g6)': dtype('int64'),
#  'PST\nSV\n(g11)': dtype('int64'),
#  'HT\nOut flow\n(a6)': dtype('int64'),
#  'HT\nOut TOC\n(a4)': dtype('int64'),
#  'HT\nOut pH\n(a2)': dtype('float64'),
#  'HT \nEmpty Volume (m³)\n(a8)': dtype('float64'),
#  'HT\nOut TN': dtype('int64'),
#  'HT\nOut TP': dtype('float64'),
#  'ACT 1 \nin TOC\n(d1)': dtype('int64'),
#  'ACT 1\nOut TOC\n(d2)': dtype('float64'),
#  'ACT 1\nin TN\n(d3)': dtype('int64'),
#  'ACT 1\nOut TN\n(d4)': dtype('float64'),
#  'ACT 1\nin TP\n(d5)': dtype('float64'),
#  'ACT 1\nOut TP\n(d6)': dtype('float64'),
#  'ACT 1\nOUR\n(d7)': dtype('float64'),
#  'ACT 1\nDO\n(d11)': dtype('O'),
#  'ACT 1\ninlet Flow\n(d12)': dtype('float64'),
#  'ACT 1\ninlet pH (d13)': dtype('float64'),
#  'ACT 1\nReactor pH\n(d18)': dtype('float64'),
#  'ACT 1\nTemp\n(d20)': dtype('float64'),
#  'ACT 1\nin Ammonia\n(d22)': dtype('float64'),
#  'ACT 1\nOut Ammonia\n(d23)': dtype('float64'),
#  'ACT 1 specialist\nSCORING\n(by Himal)': dtype('int64'),
#  'AHR\nin TOC\n(From ACT 1)\n(c1)': dtype('float64'),
#  'AHR \nOut TOC\n(c2)': dtype('int64'),
#  'AHR\nTVA\n(c3)': dtype('int64'),
#  'AHR\nAlkalinity\n(c4)': dtype('int64'),
#  'AHR\nTotal in flow\n(from PH Adjust 1)': dtype('float64'),
#  'AHR\nin Flow\n(From ACT 1)\n(c5)': dtype('float64'),
#  'AHR \nBP in Flow\n(From HT)\n(c6)': dtype('float64'),
#  'AHR\nBP in TOC\n(From HT)\n(c7)': dtype('float64'),
#  'AHR\nCirculation\n(c8) ': dtype('int64'),
#  'AHR\nMLSS\n(c9)': dtype('int64'),
#  'AHR\nTemp\n(c12)': dtype('float64'),
#  'AHR\nin PH\n(After PH Adjust)\n(c10)': dtype('float64'),
#  'AHR\nOut PH\n(c13)': dtype('float64'),
#  'ACT 2\nin TOC\n(From ACT 1)': dtype('int64'),
#  'ACT 2\nin TOC\n(From AHR)': dtype('int64'),
#  'ACT 2\nin TOC\n(y1)': dtype('int64'),
#  'ACT 2\nOut TOC\n(y2)': dtype('float64'),
#  'ACT 2\nOut TN\n(y4)': dtype('float64'),
#  'ACT 2\nOut TP\n(y6)': dtype('float64'),
#  'ACT 2\nOUR\n(y7)': dtype('float64'),
#  'ACT 2\nDO\n(y11)': dtype('float64'),
#  'ACT 2\nOut TURB': dtype('float64'),
#  'ACT 2\nOut TSS': dtype('int64'),
#  'ACT 2\ninlet Flow\n(From ACT 1)': dtype('float64'),
#  'ACT 2\ninlet Flow\n(From AHR)': dtype('int64'),
#  'ACT 2\ninlet Flow\n(y12)': dtype('int64'),
#  'ACT 2\nBP in Flow\n(From SFT)\n(y15)': dtype('int64'),
#  'ACT 2\nBP in TOC\n(From SFT)\n(y16)': dtype('int64'),
#  'ACT 2\nBP in pH\n(From SFT)\n(y14)': dtype('float64'),
#  'ACT 2\nReactor pH\n(y18)': dtype('float64'),
#  'ACT 2\nTemp\n(y20)': dtype('float64'),
#  'ASP\nin TOC\n(From ACT 2)': dtype('int64'),
#  'ASP\nin TOC\n(From AHR)': dtype('int64'),
#  'ASP\nin TOC\n(z1)': dtype('int64'),
#  'ASP\nOut TOC\n(z2)': dtype('int64'),
#  'ASP\nOut TN\n(z4)': dtype('int64'),
#  'ASP\nOut TP\n(z6)': dtype('float64'),
#  'ASP\nOUR\n(z7)': dtype('float64'),
#  'ASP\nMLSS\n(z9)': dtype('float64'),
#  'ASP\nSV\n(z10)': dtype('int64'),
#  'ASP\nDO\n(z11)': dtype('float64'),
#  'ASP\ninlet Flow\n(From ACT 2)': dtype('float64'),
#  'ASP\ninlet Flow\n(From AHR)': dtype('int64'),
#  'ASP\ninlet Flow\n(z12)': dtype('int64'),
#  'ASP\nBP in pH\n(From SFT)\n(z14)': dtype('int64'),
#  'ASP\nBP in flow\n(From SFT)\n(z15)': dtype('O'),
#  'ASP\nBP in TOC\n(From SFT)\n(z16)': dtype('int64'),
#  'ASP\nMLVSS\n(z17)': dtype('int64'),
#  'ASP\nReactor pH\n(z18)': dtype('float64'),
#  'ASP\nCirculation\n(z19)': dtype('float64'),
#  'ASP\nTemp\n(z20)': dtype('float64'),
#  'S1\nOut Turb\n(t1)': dtype('float64'),
#  'S1\nSludge Wasting\n(m³/hr)\n(t2)': dtype('float64'),
#  'S1\nVisual\n(t4)': dtype('float64'),
#  'S1\nOut TSS\n(t6)': dtype('int64'),
#  'S1\nOut TOC\n(t8)': dtype('int64'),
#  'S1\nSV\n(t10)': dtype('int64'),
#  'Post Treatment\nin FLOW\n(From S1)': dtype('int64'),
#  'Post Treatment\nin FLOW\n(From ACT 2)': dtype('int64'),
#  'Post Treatment\nin TSS\n(From S1)': dtype('int64'),
#  'Post Treatment\nin TSS\n(From ACT 2)': dtype('int64'),
#  'Post Treatment\nin TSS\n(x1)': dtype('int64'),
#  'Post Treatment\nOut TSS\n(S2 O/L)\n(x2)': dtype('int64'),
#  'Post Treatment\nin TUR\n(From S1)': dtype('int64'),
#  'Post Treatment\nin TUR\n(From ACT 2)': dtype('int64'),
#  'Post Treatment\nin TUR\n(x3)': dtype('int64'),
#  'Post Treatment\nOut TUR\n(S2 O/L)\n(x4)': dtype('float64'),
#  'Post Treatment\nin TOC\n(From S1)': dtype('float64'),
#  'Post Treatment\nin TOC\n(From ACT 2)': dtype('int64'),
#  'Post Treatment\nin TOC\n(x5)': dtype('int64'),
#  'Post Treatment\nOut TOC\n(S2 O/L)\n(x6)': dtype('int64'),
#  'Post Treatment\nOut PH\n(S2 O/L)\n(x7)': dtype('float64'),
#  'Post Treatment\nOut FLOW\n(S2 O/L)\n(X8) ': dtype('int64'),
#  'pH Adjst\nOut pH\n(From Final)\n(p1) ': dtype('float64')}

# %%
df=df.fillna(df.mean()) # filling null values with the average value

# number of rows and number of column in this excel file.
temp = df.shape
num_rows = temp[0]
num_column=temp[1]
print("Number of rows : ",num_rows)
print("Number of column : ",num_column)

temp1=df.isna().sum().sum() # after filling null value with avg count of null value
print("count of null value : ",temp1)
# Out:
# Number of rows :  358
# Number of column :  106
# count of null value :  0

# %%
df.describe() # describing whole data sheet
# Out:
#        System Flow\n(w1)  Final\nOut TOC\n(w2)  Final\nOut Turbidity\n(w3)  \
# count         358.000000            358.000000                  358.000000
# mean          203.946927            177.159218                   65.882570
# std            74.251484             40.696111                   31.443511
# min             0.000000             28.000000                   17.350000
# 25%           140.000000            159.000000                   42.200000
# 50%           230.000000            175.000000                   58.350000
# 75%           273.750000            192.000000                   82.390000
# max           290.000000            323.000000                  174.000000
#
#        Final\nOut TSS\n(w4)  Final\nOut pH\n(w8)  PST\nVisual\n(g4)  \
# count            358.000000           358.000000         358.000000
# mean             138.379888             7.003017           7.491620
# std               77.970158             0.323992           1.060462
# min               30.000000             6.460000           4.000000
# 25%               90.000000             6.800000           7.000000
# 50%              120.000000             7.000000           7.000000
# 75%              160.000000             7.000000           8.000000
# max              680.000000             8.360000          10.000000
#
#        PST\nOut PH\n(g9)  PST\nSludge Wasting\n(m³/hr)\n(g2)  \
# count         358.000000                          358.000000
# mean            7.702318                            4.757682
# std             0.233434                            5.068002
# min             7.000000                            0.000000
# 25%             7.600000                            2.000000
# 50%             7.780000                            3.000000
# 75%             7.850000                            5.000000
# max             8.370000                           20.000000
#
#        PST\nOut TSS \n(g6)  PST\nSV\n(g11)  ...  \
# count           358.000000      358.000000  ...
# mean            686.472067      925.865922  ...
# std            1208.576626       83.096272  ...
# min              70.000000      600.000000  ...
# 25%             250.000000      850.000000  ...
# 50%             300.000000      970.000000  ...
# 75%             567.500000      980.000000  ...
# max           15550.000000     1000.000000  ...
#
#        Post Treatment\nin TUR\n(From ACT 2)  Post Treatment\nin TUR\n(x3)  \
# count                            358.000000                    358.000000
# mean                             367.256983                    340.061453
# std                              243.400192                    153.101298
# min                                0.000000                      0.000000
# 25%                              150.000000                    264.250000
# 50%                              389.000000                    329.000000
# 75%                              546.000000                    400.500000
# max                              959.000000                    788.000000
#
#        Post Treatment\nOut TUR\n(S2 O/L)\n(x4)  \
# count                               358.000000
# mean                                151.592933
# std                                 126.048081
# min                                   6.140000
# 25%                                  54.960000
# 50%                                  95.920000
# 75%                                 248.750000
# max                                 587.000000
#
#        Post Treatment\nin TOC\n(From S1)  \
# count                         358.000000
# mean                           47.600894
# std                            37.116114
# min                            24.000000
# 25%                            30.000000
# 50%                            30.000000
# 75%                            50.250000
# max                           263.000000
#
#        Post Treatment\nin TOC\n(From ACT 2)  Post Treatment\nin TOC\n(x5)  \
# count                            358.000000                    358.000000
# mean                             349.631285                    441.410615
# std                              268.878172                    186.822784
# min                                0.000000                      0.000000
# 25%                               30.000000                    323.500000
# 50%                              522.500000                    414.000000
# 75%                              576.000000                    610.500000
# max                              704.000000                    882.000000
#
#        Post Treatment\nOut TOC\n(S2 O/L)\n(x6)  \
# count                               358.000000
# mean                                278.916201
# std                                 101.168100
# min                                  90.000000
# 25%                                 196.500000
# 50%                                 252.500000
# 75%                                 379.250000
# max                                 546.000000
#
#        Post Treatment\nOut PH\n(S2 O/L)\n(x7)  \
# count                              358.000000
# mean                                 6.938408
# std                                 14.517437
# min                                  4.000000
# 25%                                  5.130000
# 50%                                  5.935000
# 75%                                  6.435000
# max                                200.000000
#
#        Post Treatment\nOut FLOW\n(S2 O/L)\n(X8)   \
# count                                 358.000000
# mean                                  168.896648
# std                                    60.116162
# min                                     0.000000
# 25%                                   126.250000
# 50%                                   180.000000
# 75%                                   210.000000
# max                                   324.000000
#
#        pH Adjst\nOut pH\n(From Final)\n(p1)
# count                             358.000000
# mean                                6.064385
# std                                 1.448088
# min                                 4.000000
# 25%                                 4.000000
# 50%                                 6.800000
# 75%                                 7.000000
# max                                 8.360000
#
# [8 rows x 103 columns]

# %%
df.isnull().sum() # checking null values column wise.
# Out:
# Date                                         0
# System Flow\n(w1)                            0
# Final\nOut TOC\n(w2)                         0
# Final\nOut Turbidity\n(w3)                   0
# Final\nOut TSS\n(w4)                         0
#                                             ..
# Post Treatment\nin TOC\n(x5)                 0
# Post Treatment\nOut TOC\n(S2 O/L)\n(x6)      0
# Post Treatment\nOut PH\n(S2 O/L)\n(x7)       0
# Post Treatment\nOut FLOW\n(S2 O/L)\n(X8)     0
# pH Adjst\nOut pH\n(From Final)\n(p1)         0
# Length: 106, dtype: int64

# %%
#creating new column ACT_1_TOC_degradation

arr1=np.array(df["ACT 1 \nin TOC\n(d1)"])
arr2=np.array(df["ACT 1\nOut TOC\n(d2)"])
df["ACT_1_TOC_degradation"]=(1-(arr2/arr1))*100

# %%
df["AHR\nTotal in flow\n(from PH Adjust 1)"] #showing null value filled with mean value.
# Out:
# 0      47.1625
# 1      47.1625
# 2      47.1625
# 3      47.1625
# 4      47.1625
#         ...
# 353    55.0000
# 354    53.0000
# 355    54.0000
# 356    53.0000
# 357    56.0000
# Name: AHR\nTotal in flow\n(from PH Adjust 1), Length: 358, dtype: float64

# %%
df.describe() # describing data sheet after null value filled with mean and a new column is created.
# Out:
#        System Flow\n(w1)  Final\nOut TOC\n(w2)  Final\nOut Turbidity\n(w3)  \
# count         358.000000            358.000000                  358.000000
# mean          203.946927            177.159218                   65.882570
# std            74.251484             40.696111                   31.443511
# min             0.000000             28.000000                   17.350000
# 25%           140.000000            159.000000                   42.200000
# 50%           230.000000            175.000000                   58.350000
# 75%           273.750000            192.000000                   82.390000
# max           290.000000            323.000000                  174.000000
#
#        Final\nOut TSS\n(w4)  Final\nOut pH\n(w8)  PST\nVisual\n(g4)  \
# count            358.000000           358.000000         358.000000
# mean             138.379888             7.003017           7.491620
# std               77.970158             0.323992           1.060462
# min               30.000000             6.460000           4.000000
# 25%               90.000000             6.800000           7.000000
# 50%              120.000000             7.000000           7.000000
# 75%              160.000000             7.000000           8.000000
# max              680.000000             8.360000          10.000000
#
#        PST\nOut PH\n(g9)  PST\nSludge Wasting\n(m³/hr)\n(g2)  \
# count         358.000000                          358.000000
# mean            7.702318                            4.757682
# std             0.233434                            5.068002
# min             7.000000                            0.000000
# 25%             7.600000                            2.000000
# 50%             7.780000                            3.000000
# 75%             7.850000                            5.000000
# max             8.370000                           20.000000
#
#        PST\nOut TSS \n(g6)  PST\nSV\n(g11)  ...  Post Treatment\nin TUR\n(x3)  \
# count           358.000000      358.000000  ...                    358.000000
# mean            686.472067      925.865922  ...                    340.061453
# std            1208.576626       83.096272  ...                    153.101298
# min              70.000000      600.000000  ...                      0.000000
# 25%             250.000000      850.000000  ...                    264.250000
# 50%             300.000000      970.000000  ...                    329.000000
# 75%             567.500000      980.000000  ...                    400.500000
# max           15550.000000     1000.000000  ...                    788.000000
#
#        Post Treatment\nOut TUR\n(S2 O/L)\n(x4)  \
# count                               358.000000
# mean                                151.592933
# std                                 126.048081
# min                                   6.140000
# 25%                                  54.960000
# 50%                                  95.920000
# 75%                                 248.750000
# max                                 587.000000
#
#        Post Treatment\nin TOC\n(From S1)  \
# count                         358.000000
# mean                           47.600894
# std                            37.116114
# min                            24.000000
# 25%                            30.000000
# 50%                            30.000000
# 75%                            50.250000
# max                           263.000000
#
#        Post Treatment\nin TOC\n(From ACT 2)  Post Treatment\nin TOC\n(x5)  \
# count                            358.000000                    358.000000
# mean                             349.631285                    441.410615
# std                              268.878172                    186.822784
# min                                0.000000                      0.000000
# 25%                               30.000000                    323.500000
# 50%                              522.500000                    414.000000
# 75%                              576.000000                    610.500000
# max                              704.000000                    882.000000
#
#        Post Treatment\nOut TOC\n(S2 O/L)\n(x6)  \
# count                               358.000000
# mean                                278.916201
# std                                 101.168100
# min                                  90.000000
# 25%                                 196.500000
# 50%                                 252.500000
# 75%                                 379.250000
# max                                 546.000000
#
#        Post Treatment\nOut PH\n(S2 O/L)\n(x7)  \
# count                              358.000000
# mean                                 6.938408
# std                                 14.517437
# min                                  4.000000
# 25%                                  5.130000
# 50%                                  5.935000
# 75%                                  6.435000
# max                                200.000000
#
#        Post Treatment\nOut FLOW\n(S2 O/L)\n(X8)   \
# count                                 358.000000
# mean                                  168.896648
# std                                    60.116162
# min                                     0.000000
# 25%                                   126.250000
# 50%                                   180.000000
# 75%                                   210.000000
# max                                   324.000000
#
#        pH Adjst\nOut pH\n(From Final)\n(p1)   ACT_1_TOC_degradation
# count                             358.000000             358.000000
# mean                                6.064385              13.849755
# std                                 1.448088             448.273368
# min                                 4.000000           -8441.516854
# 25%                                 4.000000              32.483883
# 50%                                 6.800000              39.298582
# 75%                                 7.000000              45.391063
# max                                 8.360000              68.493151
#
# [8 rows x 104 columns]

# %%
df["ACT_1_TOC_degradation"] # new column
# Out:
# 0      21.666667
# 1      34.951456
# 2      44.046749
# 3      20.893855
# 4      42.472266
#          ...
# 353    28.697183
# 354    27.791772
# 355    35.450161
# 356    34.126333
# 357    32.521739
# Name: ACT_1_TOC_degradation, Length: 358, dtype: float64

# %%
temp=df.shape # after new column is created size of data sheet increased.
num_row=temp[0]
num_col=temp[1]
print("no of rows after adding new column : ",num_row)
print("no of rows after adding new column : ",num_col)
# Out:
# no of rows after adding new column :  358
# no of rows after adding new column :  107

# %%
sns.boxplot(df["ACT_1_TOC_degradation"]) # graph showing outliner of "ACT_1_TOC_degradation"
print("outliners of column ACT_1_TOC_degradation are")
print()
print(np.where(df["ACT_1_TOC_degradation"]< 0))
# Out:
# outliners of column ACT_1_TOC_degradation are
#
# (array([134, 136, 142, 148, 172], dtype=int64),)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df["ACT 1 \nin TOC\n(d1)"]) # graph showing outliner of "ACT 1 \nin TOC\n(d1)"
print("outliners of column ACT 1 in TOC(d1) are")
print()
print(np.where(df["ACT 1 \nin TOC\n(d1)"]> 1750))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# outliners of column ACT 1 in TOC(d1) are
#
# (array([ 74, 211, 258, 346, 349], dtype=int64),)

# %%
sns.boxplot(df["ACT 1\nOut TOC\n(d2)"]) # graph showing outliner of "ACT 1\nOut TOC\n(d2)"
print("outliners of column ACT 1 out TOC(d2) are")
print()
print(np.where(df["ACT 1\nOut TOC\n(d2)"]> 10000))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# outliners of column ACT 1 out TOC(d2) are
#
# (array([172], dtype=int64),)

# %%
for val in range(1,len(col_arr)):
    if val==24 or val==77:
        continue
    strr=str(col_arr[val])
    corr=df["ACT_1_TOC_degradation"].corr(df[strr])
    print("the correlation of (ACT_1_TOC_degradation) and ",strr ," is ",corr)
    print()
# Out:
# the correlation of (ACT_1_TOC_degradation) and  System Flow
# (w1)  is  0.07451145781981798
#
# the correlation of (ACT_1_TOC_degradation) and  Final
# Out TOC
# (w2)  is  0.05142693850847716
#
# the correlation of (ACT_1_TOC_degradation) and  Final
# Out Turbidity
# (w3)  is  0.022486323929889165
#
# the correlation of (ACT_1_TOC_degradation) and  Final
# Out TSS
# (w4)  is  -0.04989867765875985
#
# the correlation of (ACT_1_TOC_degradation) and  Final
# Out pH
# (w8)  is  0.011843973386322626
#
# the correlation of (ACT_1_TOC_degradation) and  PST
# Visual
# (g4)  is  0.023235298163503323
#
# the correlation of (ACT_1_TOC_degradation) and  PST
# Out PH
# (g9)  is  -0.03140076978650567
#
# the correlation of (ACT_1_TOC_degradation) and  PST
# Sludge Wasting
# (m³/hr)
# (g2)  is  0.028463587940107477
#
# the correlation of (ACT_1_TOC_degradation) and  PST
# Out TSS
# (g6)  is  0.02207627036761951
#
# the correlation of (ACT_1_TOC_degradation) and  PST
# SV
# (g11)  is  -0.0376250548313725
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Out flow
# (a6)  is  0.0662990986696418
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Out TOC
# (a4)  is  0.11569471069855272
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Out pH
# (a2)  is  -0.05290282413650525
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Empty Volume (m³)
# (a8)  is  -0.040190695175333684
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Out TN  is  -0.06287922025351668
#
# the correlation of (ACT_1_TOC_degradation) and  HT
# Out TP  is  0.01907054283527479
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# in TOC
# (d1)  is  0.11541690107302335
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Out TOC
# (d2)  is  -0.9992200069095013
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# in TN
# (d3)  is  -0.06287922025351668
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Out TN
# (d4)  is  0.02404413249857838
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# in TP
# (d5)  is  0.01907054283527479
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Out TP
# (d6)  is  0.07092511859150975
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# OUR
# (d7)  is  0.06588903054840702
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# inlet Flow
# (d12)  is  0.07766135374822818
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# inlet pH (d13)  is  -0.05290282413650525
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Reactor pH
# (d18)  is  -0.02696030543380605
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Temp
# (d20)  is  -0.006758467158721941
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# in Ammonia
# (d22)  is  -0.047463864213025134
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1
# Out Ammonia
# (d23)  is  0.0021990112764800505
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 1 specialist
# SCORING
# (by Himal)  is  0.032440630305237556
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# in TOC
# (From ACT 1)
# (c1)  is  -0.998834889503896
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Out TOC
# (c2)  is  0.04882007924762417
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# TVA
# (c3)  is  -0.12838196778617547
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Alkalinity
# (c4)  is  0.016841279026345447
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Total in flow
# (from PH Adjust 1)  is  0.0020006124616962044
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# in Flow
# (From ACT 1)
# (c5)  is  0.022275291361184252
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# BP in Flow
# (From HT)
# (c6)  is  -0.07079354536743436
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# BP in TOC
# (From HT)
# (c7)  is  -0.04559549105908101
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Circulation
# (c8)   is  0.05654164700346022
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# MLSS
# (c9)  is  -0.030059738766074474
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Temp
# (c12)  is  -0.019920448359580685
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# in PH
# (After PH Adjust)
# (c10)  is  0.011256777421350521
#
# the correlation of (ACT_1_TOC_degradation) and  AHR
# Out PH
# (c13)  is  -0.04936728326476181
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# in TOC
# (From ACT 1)  is  -0.997053415116806
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# in TOC
# (From AHR)  is  0.010949254347638623
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# in TOC
# (y1)  is  0.0259514067034272
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Out TOC
# (y2)  is  0.06367970341231102
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Out TN
# (y4)  is  0.0306042429357476
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Out TP
# (y6)  is  -0.05737241016820885
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# OUR
# (y7)  is  0.05091139722830406
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# DO
# (y11)  is  0.07213922354812166
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Out TURB  is  0.013760628161748646
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Out TSS  is  -0.05482341932689871
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# inlet Flow
# (From ACT 1)  is  0.040058528724234516
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# inlet Flow
# (From AHR)  is  -0.005032769261344516
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# inlet Flow
# (y12)  is  0.042275456250491436
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# BP in Flow
# (From SFT)
# (y15)  is  0.04211894934678293
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# BP in TOC
# (From SFT)
# (y16)  is  0.006479093100139493
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# BP in pH
# (From SFT)
# (y14)  is  0.032932859606908255
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Reactor pH
# (y18)  is  -0.04600811450743636
#
# the correlation of (ACT_1_TOC_degradation) and  ACT 2
# Temp
# (y20)  is  -0.03975112147866897
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# in TOC
# (From ACT 2)  is  0.03624699231710277
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# in TOC
# (From AHR)  is  nan
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# in TOC
# (z1)  is  nan
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Out TOC
# (z2)  is  0.010873875621409094
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Out TN
# (z4)  is  -0.02777706807070753
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Out TP
# (z6)  is  0.036564148819175704
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# OUR
# (z7)  is  0.012189527502562456
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# MLSS
# (z9)  is  -0.044279188122834066
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# SV
# (z10)  is  0.03845055297929977
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# DO
# (z11)  is  0.03607711383665937
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# inlet Flow
# (From ACT 2)  is  0.03395497034632371
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# inlet Flow
# (From AHR)  is  nan
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# inlet Flow
# (z12)  is  nan
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# BP in pH
# (From SFT)
# (z14)  is  -0.044449934009851075
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# BP in TOC
# (From SFT)
# (z16)  is  0.030332664769259762
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# MLVSS
# (z17)  is  -0.0220427992414801
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Reactor pH
# (z18)  is  0.0361340531079185
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Circulation
# (z19)  is  0.019282583856975982
#
# the correlation of (ACT_1_TOC_degradation) and  ASP
# Temp
# (z20)  is  0.028065782399662603
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# Out Turb
# (t1)  is  0.013794475548352288
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# Sludge Wasting
# (m³/hr)
# (t2)  is  0.03179207607031945
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# Visual
# (t4)  is  -0.030005475300377102
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# Out TSS
# (t6)  is  -0.06434359594000778
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# Out TOC
# (t8)  is  0.04098127137605038
#
# the correlation of (ACT_1_TOC_degradation) and  S1
# SV
# (t10)  is  -0.035614511151857896
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in FLOW
# (From S1)  is  -0.014306807686308102
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in FLOW
# (From ACT 2)  is  0.048626541831220206
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TSS
# (From S1)  is  -0.04046057765878681
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TSS
# (From ACT 2)  is  -0.09708146099012675
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TSS
# (x1)  is  -0.05154777335205319
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# Out TSS
# (S2 O/L)
# (x2)  is  0.02777552378495453
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TUR
# (From S1)  is  0.05053096607802701
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TUR
# (From ACT 2)  is  -0.008594267083428718
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TUR
# (x3)  is  0.040750063247385636
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# Out TUR
# (S2 O/L)
# (x4)  is  0.03331650280125334
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TOC
# (From S1)  is  0.02441309307654091
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TOC
# (From ACT 2)  is  -0.021420364475879132
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# in TOC
# (x5)  is  0.05001528351969327
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# Out TOC
# (S2 O/L)
# (x6)  is  0.0734506789687599
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# Out PH
# (S2 O/L)
# (x7)  is  0.0051894378942333435
#
# the correlation of (ACT_1_TOC_degradation) and  Post Treatment
# Out FLOW
# (S2 O/L)
# (X8)   is  0.05600905287383702
#
# the correlation of (ACT_1_TOC_degradation) and  pH Adjst
# Out pH
# (From Final)
# (p1)   is  -0.031001949961673908
